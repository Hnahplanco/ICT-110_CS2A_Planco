# %% [markdown]
# #Chapter 10

# %%
#Exercise 1
num = (1, 1, 2, 3, 5)
total = sum(num)
print(f"The sum of the tuple elements is:",total)
# Out:
# The sum of the tuple elements is: 12

# %%
#Exercise 2
ph_info = ('Philippines', 'Manila', 103.3)
ph_country, ph_city, ph_population = ph_info

print(f"Country: ",ph_country)
print(f"City: ",ph_city)
print(f"Population (in million): ", ph_population)
# Out:
# Country:  Philippines
# City:  Manila
# Population (in million):  103.3
