# %%
name=input("Enter Your Name: ")
print("Hello " + name+ "!")
# Out:
# Enter Your Name: Hannah
# Hello Hannah!

# %%
x = 1 - 2.5
print(x)
print(type(x))
# Out:
# -1.5
# <class 'float'>

# %%
string_var='2020'
int_var=int(string_var)
add=int_var+20
print(add)

# %%
#Exercise 1
name=input("Enter Your Name: ")
print("Hello " + name+ "!")
# Out:
# Enter Your Name: Hannah
# Hello Hannah!

# %%
#Exercise 2
Hours=int(input("Enter working hours: "))
rate=float(input("Enter rate; "))
pay=Hours*rate
print("Pay: ",pay)
# Out:
# Enter working hours: 35
# Enter rate; 2.75
# Pay:  96.25

# %%
#Exercise 3
width=17
height= 12.0
print(width//2)
print(type (width))
print(width/2.0)
print(type (width))
print(height/3)
print(type (height))
print(1+2*5)
# Out:
# 8
# <class 'int'>
# 8.5
# <class 'int'>
# 4.0
# <class 'float'>
# 11

# %%
#Exercise 4
num=int(input("Enter a number: "))
square=num*num
print("The square of ", num)
print("is",square)
# Out:
# Enter a number: 3
# The square of  3
# is 9

# %%
#CHALLENGE
celsius=float(input("Enter a temperature in celsius: "))
fahrenheit=(celsius*1.8)+32
print("Fahrenheit: ",fahrenheit)
# Out:
# Enter a temperature in celsius: 38
# Fahrenheit:  100.4

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
'hello world'
# Out:
# 'hello world'

# %%
"hello world"
# Out:
# 'hello world'

# %%
x=45
x=x*2
x
# Out:
# 90

# %%
e
# Out:
#   File "<ipython-input-13-79f7a08ef9d8>", line 5
#     else
#         ^
# SyntaxError: expected ':'
